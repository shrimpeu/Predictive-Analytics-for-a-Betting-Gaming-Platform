# %% [markdown]
# # Sports Betting Data Cleaning and Preprocessing
#
# ## Introduction
# This notebook aims to analyze historical game statistics and betting odds data to develop predictive models for sports betting. The dataset consists of game statistics and betting odds, which we will preprocess and engineer to create meaningful features for analysis.

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ### Extract Datasets
# We begin by extract the game statistics (`Game.csv`) and betting odds (`BettingOdds_History.csv`) datasets into Pandas DataFrames.

# %%
game_stats_path = 'datasets/Game.csv'
betting_odds_path = 'datasets/BettingOdds_History.csv'

game_stats = pd.read_csv(game_stats_path)
betting_odds = pd.read_csv(betting_odds_path)

# %% [markdown]
# ## Preprocessing and Cleaning
#
# ### Handling Missing Values in Game Statistics Data
#
# We begin by handling missing values in the game statistics dataset. Rows with missing `GAME_ID` are removed. For numeric columns, missing values are filled with the column mean. Rows with more than 20% missing data are also removed.

# %%
# Handle missing values in game stats data
game_stats.dropna(subset=['GAME_ID'], inplace=True)

# %%
# Fill missing numeric data with mean or placeholder value
numeric_cols = game_stats.select_dtypes(include=[np.number]).columns
game_stats[numeric_cols] = game_stats[numeric_cols].fillna(game_stats[numeric_cols].mean())

# %%
game_stats.dropna(thresh=int(0.8 * len(game_stats.columns)), inplace=True)

# %% [markdown]
# ### Handling Team Names and Abbreviations in Game Statistics Data
# In this step, we will clean the dataset by standardizing the names of NBA teams that have undergone name changes or relocations over time. This ensures consistency in the data, which is essential for accurate analysis and modeling.

# %% [markdown]
# Identify and inspect the columns that contain team names and abbreviations to understand how they are represented in the dataset.

# %%
df = game_stats
# Get unique values for team names and abbreviations
print(df['TEAM_NAME_HOME'].unique())
print(df['TEAM_ABBREVIATION_HOME'].unique())
# Out:
# ['Toronto Huskies' 'Chicago Stags' 'St. Louis Bombers'
#  'Providence Steamrollers' 'Detroit Falcons' 'Cleveland Rebels'
#  'Pittsburgh Ironmen' 'Boston Celtics' 'Philadelphia Warriors'
#  'New York Knicks' 'Washington Capitols' 'Baltimore Bullets'
#  'Indianapolis Jets' 'Ft. Wayne Zollner Pistons' 'Rochester Royals'
#  'Minneapolis Lakers' 'Tri-Cities Blackhawks' 'Indianapolis Olympians'
#  'Waterloo Hawks' 'Syracuse Nationals' 'Anderson Packers'
#  'Sheboygan Redskins' 'Denver Nuggets' 'Milwaukee Hawks' 'St. Louis Hawks'
#  'Detroit Pistons' 'Cincinnati Royals' 'Los Angeles Lakers'
#  'Chicago Packers' 'Chicago Zephyrs' 'San Francisco Warriors'
#  'Philadelphia 76ers' 'Chicago Bulls' 'San Diego Rockets'
#  'Seattle SuperSonics' 'Atlanta Hawks' 'Milwaukee Bucks' 'Phoenix Suns'
#  'Buffalo Braves' 'Portland Trail Blazers' 'Cleveland Cavaliers'
#  'Houston Rockets' 'Golden State Warriors' 'Kansas City-Omaha Kings'
#  'Capital Bullets' 'Washington Bullets' 'New Orleans Jazz'
#  'Kansas City Kings' 'Indiana Pacers' 'San Antonio Spurs' 'New York Nets'
#  'New Jersey Nets' 'San Diego Clippers' 'Utah Jazz' 'Dallas Mavericks'
#  'Los Angeles Clippers' 'Sacramento Kings' 'Charlotte Hornets'
#  'Miami Heat' 'Orlando Magic' 'Minnesota Timberwolves' 'Toronto Raptors'
#  'Vancouver Grizzlies' 'Washington Wizards' 'Memphis Grizzlies'
#  'New Orleans Hornets' 'Charlotte Bobcats'
#  'New Orleans/Oklahoma City Hornets' 'Oklahoma City Thunder'
#  'Brooklyn Nets' 'New Orleans Pelicans' 'LA Clippers']
# ['HUS' 'CHS' 'BOM' 'PRO' 'DEF' 'CLR' 'PIT' 'BOS' 'PHW' 'NYK' 'WAS' 'BAL'
#  'JET' 'FTW' 'ROC' 'MNL' 'TCB' 'INO' 'WAT' 'SYR' 'AND' 'SHE' 'DN' 'MIH'
#  'STL' 'DET' 'CIN' 'LAL' 'CHP' 'CHZ' 'SFW' 'BLT' 'PHL' 'CHI' 'SDR' 'SEA'
#  'ATL' 'MIL' 'PHX' 'BUF' 'POR' 'CLE' 'HOU' 'GOS' 'KCK' 'CAP' 'NOJ' 'IND'
#  'DEN' 'SAN' 'NYN' 'NJN' 'SDC' 'UTH' 'DAL' 'LAC' 'SAC' 'CHH' 'MIA' 'ORL'
#  'MIN' 'TOR' 'VAN' 'UTA' 'PHI' 'GSW' 'SAS' 'MEM' 'NOH' 'CHA' 'NOK' 'OKC'
#  'BKN' 'NOP']

# %% [markdown]
# We will create a dictionary that maps old team names to their current or standardized versions. Specifically, we will:
#
# 1. Replace `Charlotte Bobcats` with `Charlotte Hornets` and update the abbreviation to `CHA`.
# 2. Replace `New Jersey Nets` with `Brooklyn Nets` and update the abbreviation to `BKN`.
# 3. Replace `New Orleans Hornets` with `New Orleans Pelicans` and update the abbreviation to `NOP`.
# 4. Replace `Seattle SuperSonics` with `Oklahoma City Thunder` and update the abbreviation to `OKC`.
# 5. Standardize `Los Angeles Clippers` to `LA Clippers` and update the abbreviation to `LAC`.
#
# This cleaning process will be applied to both the away and home team columns.

# %%
# Dictionary for name replacements
team_name_changes = {
    'Charlotte Bobcats': 'Charlotte Hornets',
    'New Jersey Nets': 'Brooklyn Nets',
    'New Orleans Hornets': 'New Orleans Pelicans',
    'Seattle SuperSonics': 'Oklahoma City Thunder',
    'Los Angeles Clippers': 'LA Clippers'
}

# Dictionary for abbreviation updates
team_abbreviation_changes = {
    'Charlotte Hornets': 'CHA',
    'Brooklyn Nets': 'BKN',
    'New Orleans Pelicans': 'NOP',
    'Oklahoma City Thunder': 'OKC',
    'LA Clippers': 'LAC'
}

# Replace team names in away and home columns
df['TEAM_NAME_AWAY'] = df['TEAM_NAME_AWAY'].replace(team_name_changes)
df['TEAM_NAME_HOME'] = df['TEAM_NAME_HOME'].replace(team_name_changes)

# Replace abbreviations based on updated team names
df['TEAM_ABBREVIATION_AWAY'] = df['TEAM_NAME_AWAY'].map(team_abbreviation_changes).fillna(df['TEAM_ABBREVIATION_AWAY'])
df['TEAM_ABBREVIATION_HOME'] = df['TEAM_NAME_HOME'].map(team_abbreviation_changes).fillna(df['TEAM_ABBREVIATION_HOME'])

# Display the cleaned DataFrame
print(df)
# Out:
#         GAME_ID  SEASON_ID  TEAM_ID_AWAY TEAM_ABBREVIATION_AWAY  \
# 0      24600001      21946    1610612752                    NYK
# 1      24600004      21946    1610612752                    NYK
# 2      24600003      21946    1610610031                    PIT
# 3      24600002      21946    1610612738                    BOS
# 4      24600005      21946    1610610036                    WAS
# ...         ...        ...           ...                    ...
# 62857  22100488      22021    1610612737                    ATL
# 62858  22100489      22021    1610612738                    BOS
# 62859  22100490      22021    1610612744                    GSW
# 62860  22100491      22021    1610612751                    BKN
# 62861  22100492      22021    1610612742                    DAL
#
#               TEAM_NAME_AWAY GAME_DATE_AWAY MATCHUP_AWAY WL_AWAY  MIN_AWAY  \
# 0            New York Knicks     1946-11-01    NYK @ HUS       W         0
# 1            New York Knicks     1946-11-02    NYK @ CHS       L         0
# 2         Pittsburgh Ironmen     1946-11-02    PIT @ BOM       L         0
# 3             Boston Celtics     1946-11-02    BOS @ PRO       L         0
# 4        Washington Capitols     1946-11-02    WAS @ DEF       W         0
# ...                      ...            ...          ...     ...       ...
# 62857          Atlanta Hawks     2021-12-25    ATL @ NYK       L       240
# 62858         Boston Celtics     2021-12-25    BOS @ MIL       L       240
# 62859  Golden State Warriors     2021-12-25    GSW @ PHX       W       240
# 62860          Brooklyn Nets     2021-12-25    BKN @ LAL       W       240
# 62861       Dallas Mavericks     2021-12-25    DAL @ UTA       L       240
#
#        FGM_AWAY  ...  DREB_HOME   REB_HOME  AST_HOME  STL_HOME  BLK_HOME  \
# 0          24.0  ...  31.267284  43.765853  23.95847  8.008697  5.351333
# 1          16.0  ...  31.267284  43.765853  23.95847  8.008697  5.351333
# 2          16.0  ...  31.267284  43.765853  23.95847  8.008697  5.351333
# 3          21.0  ...  31.267284  43.765853  23.95847  8.008697  5.351333
# 4          18.0  ...  31.267284  43.765853  23.95847  8.008697  5.351333
# ...         ...  ...        ...        ...       ...       ...       ...
# 62857      33.0  ...  41.000000  50.000000  28.00000  6.000000  6.000000
# 62858      38.0  ...  33.000000  48.000000  24.00000  7.000000  6.000000
# 62859      42.0  ...  28.000000  37.000000  20.00000  5.000000  2.000000
# 62860      43.0  ...  35.000000  47.000000  29.00000  8.000000  5.000000
# 62861      38.0  ...  36.000000  49.000000  24.00000  9.000000  6.000000
#
#         TOV_HOME    PF_HOME  PTS_HOME  PLUS_MINUS_HOME  VIDEO_AVAILABLE_HOME
# 0      14.776821  22.447318        66               -2                     0
# 1      14.776821  20.000000        63               16                     0
# 2      14.776821  21.000000        56                5                     0
# 3      14.776821  22.447318        59                6                     0
# 4      14.776821  22.447318        33              -17                     0
# ...          ...        ...       ...              ...                   ...
# 62857  10.000000  13.000000       101               14                     1
# 62858  13.000000  20.000000       117                4                     1
# 62859  13.000000  17.000000       107               -9                     1
# 62860  14.000000  23.000000       115               -7                     1
# 62861  14.000000  24.000000       120                4                     1
#
# [62862 rows x 56 columns]

# %%
# Verify if the team name and abbreviation are all updated
print(df['TEAM_NAME_HOME'].unique())
print(df['TEAM_ABBREVIATION_HOME'].unique())
# Out:
# ['Toronto Huskies' 'Chicago Stags' 'St. Louis Bombers'
#  'Providence Steamrollers' 'Detroit Falcons' 'Cleveland Rebels'
#  'Pittsburgh Ironmen' 'Boston Celtics' 'Philadelphia Warriors'
#  'New York Knicks' 'Washington Capitols' 'Baltimore Bullets'
#  'Indianapolis Jets' 'Ft. Wayne Zollner Pistons' 'Rochester Royals'
#  'Minneapolis Lakers' 'Tri-Cities Blackhawks' 'Indianapolis Olympians'
#  'Waterloo Hawks' 'Syracuse Nationals' 'Anderson Packers'
#  'Sheboygan Redskins' 'Denver Nuggets' 'Milwaukee Hawks' 'St. Louis Hawks'
#  'Detroit Pistons' 'Cincinnati Royals' 'Los Angeles Lakers'
#  'Chicago Packers' 'Chicago Zephyrs' 'San Francisco Warriors'
#  'Philadelphia 76ers' 'Chicago Bulls' 'San Diego Rockets'
#  'Oklahoma City Thunder' 'Atlanta Hawks' 'Milwaukee Bucks' 'Phoenix Suns'
#  'Buffalo Braves' 'Portland Trail Blazers' 'Cleveland Cavaliers'
#  'Houston Rockets' 'Golden State Warriors' 'Kansas City-Omaha Kings'
#  'Capital Bullets' 'Washington Bullets' 'New Orleans Jazz'
#  'Kansas City Kings' 'Indiana Pacers' 'San Antonio Spurs' 'New York Nets'
#  'Brooklyn Nets' 'San Diego Clippers' 'Utah Jazz' 'Dallas Mavericks'
#  'LA Clippers' 'Sacramento Kings' 'Charlotte Hornets' 'Miami Heat'
#  'Orlando Magic' 'Minnesota Timberwolves' 'Toronto Raptors'
#  'Vancouver Grizzlies' 'Washington Wizards' 'Memphis Grizzlies'
#  'New Orleans Pelicans' 'New Orleans/Oklahoma City Hornets']
# ['HUS' 'CHS' 'BOM' 'PRO' 'DEF' 'CLR' 'PIT' 'BOS' 'PHW' 'NYK' 'WAS' 'BAL'
#  'JET' 'FTW' 'ROC' 'MNL' 'TCB' 'INO' 'WAT' 'SYR' 'AND' 'SHE' 'DN' 'MIH'
#  'STL' 'DET' 'CIN' 'LAL' 'CHP' 'CHZ' 'SFW' 'BLT' 'PHL' 'CHI' 'SDR' 'OKC'
#  'ATL' 'MIL' 'PHX' 'BUF' 'POR' 'CLE' 'HOU' 'GOS' 'KCK' 'CAP' 'NOJ' 'IND'
#  'DEN' 'SAN' 'NYN' 'BKN' 'SDC' 'UTH' 'DAL' 'LAC' 'SAC' 'CHA' 'MIA' 'ORL'
#  'MIN' 'TOR' 'VAN' 'UTA' 'PHI' 'GSW' 'SAS' 'MEM' 'NOP' 'NOK']

# %% [markdown]
# ### Handling Missing Values in Betting Odds Data
#
# Similarly, we handle missing values in the betting odds dataset. Rows with missing `GAME_ID` are removed, and numeric columns are filled with their mean. Additionally, rows with missing values in key columns like `HomeSpread_AtClose` and `HomeML` are removed.

# %%
# Handle missing values in betting odds data
betting_odds.dropna(subset=['GAME_ID'], inplace=True)

# %%
# Fill missing numeric data with mean
betting_numeric_cols = betting_odds.select_dtypes(include=[np.number]).columns
betting_odds[betting_numeric_cols] = betting_odds[betting_numeric_cols].fillna(betting_odds[betting_numeric_cols].mean())

# %%
betting_odds.dropna(subset=['HomeSpread_AtClose', 'HomeML'], inplace=True)

# %%
game_stats.head()
# Out:
#     GAME_ID  SEASON_ID  TEAM_ID_AWAY TEAM_ABBREVIATION_AWAY  \
# 0  24600001      21946    1610612752                    NYK
# 1  24600004      21946    1610612752                    NYK
# 2  24600003      21946    1610610031                    PIT
# 3  24600002      21946    1610612738                    BOS
# 4  24600005      21946    1610610036                    WAS
#
#         TEAM_NAME_AWAY GAME_DATE_AWAY MATCHUP_AWAY WL_AWAY  MIN_AWAY  \
# 0      New York Knicks     1946-11-01    NYK @ HUS       W         0
# 1      New York Knicks     1946-11-02    NYK @ CHS       L         0
# 2   Pittsburgh Ironmen     1946-11-02    PIT @ BOM       L         0
# 3       Boston Celtics     1946-11-02    BOS @ PRO       L         0
# 4  Washington Capitols     1946-11-02    WAS @ DEF       W         0
#
#    FGM_AWAY  ...  DREB_HOME   REB_HOME  AST_HOME  STL_HOME  BLK_HOME  \
# 0      24.0  ...  31.267284  43.765853  23.95847  8.008697  5.351333
# 1      16.0  ...  31.267284  43.765853  23.95847  8.008697  5.351333
# 2      16.0  ...  31.267284  43.765853  23.95847  8.008697  5.351333
# 3      21.0  ...  31.267284  43.765853  23.95847  8.008697  5.351333
# 4      18.0  ...  31.267284  43.765853  23.95847  8.008697  5.351333
#
#     TOV_HOME    PF_HOME  PTS_HOME  PLUS_MINUS_HOME  VIDEO_AVAILABLE_HOME
# 0  14.776821  22.447318        66               -2                     0
# 1  14.776821  20.000000        63               16                     0
# 2  14.776821  21.000000        56                5                     0
# 3  14.776821  22.447318        59                6                     0
# 4  14.776821  22.447318        33              -17                     0
#
# [5 rows x 56 columns]

# %%
betting_odds.head()
# Out:
#     GAME_ID                 Date HomeTeam AwayTeam  HomeSpread_AtOpen  \
# 0  20700001  2007-10-30 00:00:00      SAS      POR              -12.5
# 1  20700003  2007-10-30 00:00:00      GSW      UTA               -3.0
# 2  20700002  2007-10-30 00:00:00      LAL      HOU                2.5
# 3  20700004  2007-10-31 00:00:00      TOR      PHI               -6.5
# 4  20700006  2007-10-31 00:00:00      IND      WAS               -1.5
#
#    HomeSpread_AtClose  Over_AtOpen  Over_AtClose HomeML AwayML  2H_HomeSpread  \
# 0               -13.0        184.0         189.5  -1400    900           -5.0
# 1                -1.0        214.5         212.0   -120    100           -3.0
# 2                 5.0        191.0         199.0    190   -230            3.0
# 3                -6.5        190.0         191.0   -305    255           -2.0
# 4                 1.5        200.0         203.5    105   -125            1.0
#
#    2H_Over
# 0     95.0
# 1    105.5
# 2     99.0
# 3     96.5
# 4    105.0

# %% [markdown]
# ### Merging the Datasets
#
# We merge the cleaned game statistics and betting odds datasets on the `GAME_ID` column.

# %%
# Merge the two dataframes on the common 'GAME_ID' column
merged_df = pd.merge(game_stats, betting_odds, on='GAME_ID')
merged_df.head()
# Out:
#     GAME_ID  SEASON_ID  TEAM_ID_AWAY TEAM_ABBREVIATION_AWAY  \
# 0  20700003      22007    1610612762                    UTA
# 1  20700001      22007    1610612757                    POR
# 2  20700002      22007    1610612745                    HOU
# 3  20700007      22007    1610612741                    CHI
# 4  20700005      22007    1610612749                    MIL
#
#            TEAM_NAME_AWAY GAME_DATE_AWAY MATCHUP_AWAY WL_AWAY  MIN_AWAY  \
# 0               Utah Jazz     2007-10-30    UTA @ GSW       W       240
# 1  Portland Trail Blazers     2007-10-30    POR @ SAS       L       240
# 2         Houston Rockets     2007-10-30    HOU @ LAL       W       240
# 3           Chicago Bulls     2007-10-31    CHI @ NJN       L       265
# 4         Milwaukee Bucks     2007-10-31    MIL @ ORL       L       240
#
#    FGM_AWAY  ...  HomeTeam  AwayTeam  HomeSpread_AtOpen  HomeSpread_AtClose  \
# 0      41.0  ...       GSW       UTA               -3.0                -1.0
# 1      39.0  ...       SAS       POR              -12.5               -13.0
# 2      34.0  ...       LAL       HOU                2.5                 5.0
# 3      38.0  ...       NJN       CHI               -2.0                -1.5
# 4      33.0  ...       ORL       MIL               -8.0                -6.5
#
#    Over_AtOpen  Over_AtClose  HomeML  AwayML  2H_HomeSpread  2H_Over
# 0        214.5         212.0    -120     100           -3.0    105.5
# 1        184.0         189.5   -1400     900           -5.0     95.0
# 2        191.0         199.0     190    -230            3.0     99.0
# 3        188.0         186.0    -125     105            3.0     94.0
# 4        198.5         197.0    -295     245           -3.5     97.0
#
# [5 rows x 67 columns]

# %% [markdown]
# ### Drop Same Value Columns

# %%
# Drop the 'Date' and 'GAME_DATE_HOME' columns from merged_df
merged_df = merged_df.drop(columns=['Date', 'GAME_DATE_HOME'])

# Rename the 'GAME_DATE_AWAY' column to 'GAME_DATE'
merged_df = merged_df.rename(columns={'GAME_DATE_AWAY': 'GAME_DATE'})

# %%
merged_df.head()
# Out:
#     GAME_ID  SEASON_ID  TEAM_ID_AWAY TEAM_ABBREVIATION_AWAY  \
# 0  20700003      22007    1610612762                    UTA
# 1  20700001      22007    1610612757                    POR
# 2  20700002      22007    1610612745                    HOU
# 3  20700007      22007    1610612741                    CHI
# 4  20700005      22007    1610612749                    MIL
#
#            TEAM_NAME_AWAY   GAME_DATE MATCHUP_AWAY WL_AWAY  MIN_AWAY  \
# 0               Utah Jazz  2007-10-30    UTA @ GSW       W       240
# 1  Portland Trail Blazers  2007-10-30    POR @ SAS       L       240
# 2         Houston Rockets  2007-10-30    HOU @ LAL       W       240
# 3           Chicago Bulls  2007-10-31    CHI @ NJN       L       265
# 4         Milwaukee Bucks  2007-10-31    MIL @ ORL       L       240
#
#    FGM_AWAY  ...  HomeTeam  AwayTeam  HomeSpread_AtOpen  HomeSpread_AtClose  \
# 0      41.0  ...       GSW       UTA               -3.0                -1.0
# 1      39.0  ...       SAS       POR              -12.5               -13.0
# 2      34.0  ...       LAL       HOU                2.5                 5.0
# 3      38.0  ...       NJN       CHI               -2.0                -1.5
# 4      33.0  ...       ORL       MIL               -8.0                -6.5
#
#    Over_AtOpen  Over_AtClose  HomeML  AwayML  2H_HomeSpread  2H_Over
# 0        214.5         212.0    -120     100           -3.0    105.5
# 1        184.0         189.5   -1400     900           -5.0     95.0
# 2        191.0         199.0     190    -230            3.0     99.0
# 3        188.0         186.0    -125     105            3.0     94.0
# 4        198.5         197.0    -295     245           -3.5     97.0
#
# [5 rows x 65 columns]

# %% [markdown]
# ## Feature Engineering
#
# In this section, we perform various feature engineering steps on basketball game data, including calculating win columns, efficiency metrics, win streaks, and betting odds features.

# %% [markdown]
# ### Create Win Column
#
# In this step, we create a new column called `Win` in the `merged_df` DataFrame. This column indicates whether the home team won the game. The value is set to `1` if the points scored by the home team (`PTS_HOME`) are greater than the points scored by the away team (`PTS_AWAY`), and `0` otherwise.

# %%
# Create win column
merged_df['Win'] = (merged_df['PTS_HOME'] > merged_df['PTS_AWAY']).astype(int)
merged_df.head()
# Out:
#     GAME_ID  SEASON_ID  TEAM_ID_AWAY TEAM_ABBREVIATION_AWAY  \
# 0  20700003      22007    1610612762                    UTA
# 1  20700001      22007    1610612757                    POR
# 2  20700002      22007    1610612745                    HOU
# 3  20700007      22007    1610612741                    CHI
# 4  20700005      22007    1610612749                    MIL
#
#            TEAM_NAME_AWAY   GAME_DATE MATCHUP_AWAY WL_AWAY  MIN_AWAY  \
# 0               Utah Jazz  2007-10-30    UTA @ GSW       W       240
# 1  Portland Trail Blazers  2007-10-30    POR @ SAS       L       240
# 2         Houston Rockets  2007-10-30    HOU @ LAL       W       240
# 3           Chicago Bulls  2007-10-31    CHI @ NJN       L       265
# 4         Milwaukee Bucks  2007-10-31    MIL @ ORL       L       240
#
#    FGM_AWAY  ...  AwayTeam  HomeSpread_AtOpen  HomeSpread_AtClose  \
# 0      41.0  ...       UTA               -3.0                -1.0
# 1      39.0  ...       POR              -12.5               -13.0
# 2      34.0  ...       HOU                2.5                 5.0
# 3      38.0  ...       CHI               -2.0                -1.5
# 4      33.0  ...       MIL               -8.0                -6.5
#
#    Over_AtOpen  Over_AtClose  HomeML  AwayML  2H_HomeSpread  2H_Over  Win
# 0        214.5         212.0    -120     100           -3.0    105.5    0
# 1        184.0         189.5   -1400     900           -5.0     95.0    1
# 2        191.0         199.0     190    -230            3.0     99.0    0
# 3        188.0         186.0    -125     105            3.0     94.0    1
# 4        198.5         197.0    -295     245           -3.5     97.0    1
#
# [5 rows x 66 columns]

# %% [markdown]
# ### Convert Date Column to Datetime Format
#
# Ensure that the date column is in the correct datetime format for proper time series operations.

# %%
merged_df['GAME_DATE'].head()
# Out:
# 0    2007-10-30
# 1    2007-10-30
# 2    2007-10-30
# 3    2007-10-31
# 4    2007-10-31
# Name: GAME_DATE, dtype: object

# %%
# Ensure 'GAME_DATE' is in datetime format
merged_df['GAME_DATE'] = pd.to_datetime(merged_df['GAME_DATE'])

# Convert 'GAME_DATE' to date (removing the time part)
merged_df['GAME_DATE'] = merged_df['GAME_DATE'].dt.date

merged_df['GAME_DATE'].head()
# Out:
# 0    2007-10-30
# 1    2007-10-30
# 2    2007-10-30
# 3    2007-10-31
# 4    2007-10-31
# Name: GAME_DATE, dtype: object

# %% [markdown]
# ### Sort DataFrame by Team and Date
#
# Sort the DataFrame by the home team and date to prepare for calculating win streaks.

# %%
# Sort dataframe by team and date 
merged_df = merged_df.sort_values(by=['HomeTeam', 'GAME_DATE'])
merged_df.head()
# Out:
#       GAME_ID  SEASON_ID  TEAM_ID_AWAY TEAM_ABBREVIATION_AWAY  \
# 23   20700019      22007    1610612742                    DAL
# 59   20700056      22007    1610612756                    PHX
# 89   20700086      22007    1610612764                    WAS
# 110  20700106      22007    1610612766                    CHA
# 125  20700123      22007    1610612760                    OKC
#
#             TEAM_NAME_AWAY   GAME_DATE MATCHUP_AWAY WL_AWAY  MIN_AWAY  \
# 23        Dallas Mavericks  2007-11-02    DAL @ ATL       L       240
# 59            Phoenix Suns  2007-11-07    PHX @ ATL       L       240
# 89      Washington Wizards  2007-11-11    WAS @ ATL       W       240
# 110      Charlotte Hornets  2007-11-14    CHA @ ATL       L       240
# 125  Oklahoma City Thunder  2007-11-16    SEA @ ATL       W       290
#
#      FGM_AWAY  ...  AwayTeam  HomeSpread_AtOpen  HomeSpread_AtClose  \
# 23       35.0  ...       DAL                6.0                 5.5
# 59       35.0  ...       PHX                5.5                 5.0
# 89       38.0  ...       WAS               -5.0                -5.5
# 110      41.0  ...       CHA               -5.0                -5.5
# 125      47.0  ...       SEA               -7.5                -6.0
#
#      Over_AtOpen  Over_AtClose  HomeML  AwayML  2H_HomeSpread  2H_Over  Win
# 23         192.0         191.0     210    -250            5.0     94.5    1
# 59         208.5         207.0     190    -230            5.0    103.5    1
# 89         195.5         192.5    -230     190           -5.0    100.0    0
# 110        187.5         188.0    -240     200            1.5     93.5    1
# 125        206.0         204.5    -275     235           -5.5    100.5    0
#
# [5 rows x 66 columns]

# %% [markdown]
# ### Calculate Win Streaks for Home and Away Teams
#
# Create columns to track win streaks for both home and away teams.

# %%
# Create a win streak column for the home team
merged_df['HomeWinStreak'] = merged_df.groupby('HomeTeam')['Win'].transform(lambda x: x * (x.groupby((x != x.shift()).cumsum()).cumcount() + 1))

# Create a win streak column for the away team
merged_df['AwayWinStreak'] = merged_df.groupby('AwayTeam')['Win'].transform(lambda x: x * (x.groupby((x != x.shift()).cumsum()).cumcount() + 1))

# %%
merged_df.head()
# Out:
#       GAME_ID  SEASON_ID  TEAM_ID_AWAY TEAM_ABBREVIATION_AWAY  \
# 23   20700019      22007    1610612742                    DAL
# 59   20700056      22007    1610612756                    PHX
# 89   20700086      22007    1610612764                    WAS
# 110  20700106      22007    1610612766                    CHA
# 125  20700123      22007    1610612760                    OKC
#
#             TEAM_NAME_AWAY   GAME_DATE MATCHUP_AWAY WL_AWAY  MIN_AWAY  \
# 23        Dallas Mavericks  2007-11-02    DAL @ ATL       L       240
# 59            Phoenix Suns  2007-11-07    PHX @ ATL       L       240
# 89      Washington Wizards  2007-11-11    WAS @ ATL       W       240
# 110      Charlotte Hornets  2007-11-14    CHA @ ATL       L       240
# 125  Oklahoma City Thunder  2007-11-16    SEA @ ATL       W       290
#
#      FGM_AWAY  ...  HomeSpread_AtClose  Over_AtOpen  Over_AtClose  HomeML  \
# 23       35.0  ...                 5.5        192.0         191.0     210
# 59       35.0  ...                 5.0        208.5         207.0     190
# 89       38.0  ...                -5.5        195.5         192.5    -230
# 110      41.0  ...                -5.5        187.5         188.0    -240
# 125      47.0  ...                -6.0        206.0         204.5    -275
#
#      AwayML  2H_HomeSpread  2H_Over  Win  HomeWinStreak  AwayWinStreak
# 23     -250            5.0     94.5    1              1              1
# 59     -230            5.0    103.5    1              2              1
# 89      190           -5.0    100.0    0              0              0
# 110     200            1.5     93.5    1              1              1
# 125     235           -5.5    100.5    0              0              0
#
# [5 rows x 68 columns]

# %% [markdown]
# ### Calculate Point Difference
#
# Compute the point difference between home and away teams.

# %%
# Calculate point difference
merged_df['POINT_DIFF'] = merged_df['PTS_HOME'] - merged_df['PTS_AWAY']
merged_df.head()
# Out:
#       GAME_ID  SEASON_ID  TEAM_ID_AWAY TEAM_ABBREVIATION_AWAY  \
# 23   20700019      22007    1610612742                    DAL
# 59   20700056      22007    1610612756                    PHX
# 89   20700086      22007    1610612764                    WAS
# 110  20700106      22007    1610612766                    CHA
# 125  20700123      22007    1610612760                    OKC
#
#             TEAM_NAME_AWAY   GAME_DATE MATCHUP_AWAY WL_AWAY  MIN_AWAY  \
# 23        Dallas Mavericks  2007-11-02    DAL @ ATL       L       240
# 59            Phoenix Suns  2007-11-07    PHX @ ATL       L       240
# 89      Washington Wizards  2007-11-11    WAS @ ATL       W       240
# 110      Charlotte Hornets  2007-11-14    CHA @ ATL       L       240
# 125  Oklahoma City Thunder  2007-11-16    SEA @ ATL       W       290
#
#      FGM_AWAY  ...  Over_AtOpen  Over_AtClose  HomeML  AwayML  2H_HomeSpread  \
# 23       35.0  ...        192.0         191.0     210    -250            5.0
# 59       35.0  ...        208.5         207.0     190    -230            5.0
# 89       38.0  ...        195.5         192.5    -230     190           -5.0
# 110      41.0  ...        187.5         188.0    -240     200            1.5
# 125      47.0  ...        206.0         204.5    -275     235           -5.5
#
#      2H_Over  Win  HomeWinStreak  AwayWinStreak  POINT_DIFF
# 23      94.5    1              1              1           7
# 59     103.5    1              2              1           9
# 89     100.0    0              0              0         -11
# 110     93.5    1              1              1           8
# 125    100.5    0              0              0          -3
#
# [5 rows x 69 columns]

# %% [markdown]
# ### Calculate Efficiency Metrics
#
# Compute field goal, three-point, and free throw efficiency for both home and away teams.

# %%
# Field goal efficiency
merged_df['FG_EFF_HOME'] = merged_df['FGM_HOME'] / merged_df['FGA_HOME']
merged_df['FG_EFF_AWAY'] = merged_df['FGM_AWAY'] / merged_df['FGA_AWAY']

# Three-point efficiency
merged_df['FG3_EFF_HOME'] = merged_df['FG3M_HOME'] / merged_df['FG3A_HOME']
merged_df['FG3_EFF_AWAY'] = merged_df['FG3M_AWAY'] / merged_df['FG3A_AWAY']

# Free throw efficiency
merged_df['FT_EFF_HOME'] = merged_df['FTM_HOME'] / merged_df['FTA_HOME']
merged_df['FT_EFF_AWAY'] = merged_df['FTM_AWAY'] / merged_df['FTA_AWAY']

# %%
merged_df.head()
# Out:
#       GAME_ID  SEASON_ID  TEAM_ID_AWAY TEAM_ABBREVIATION_AWAY  \
# 23   20700019      22007    1610612742                    DAL
# 59   20700056      22007    1610612756                    PHX
# 89   20700086      22007    1610612764                    WAS
# 110  20700106      22007    1610612766                    CHA
# 125  20700123      22007    1610612760                    OKC
#
#             TEAM_NAME_AWAY   GAME_DATE MATCHUP_AWAY WL_AWAY  MIN_AWAY  \
# 23        Dallas Mavericks  2007-11-02    DAL @ ATL       L       240
# 59            Phoenix Suns  2007-11-07    PHX @ ATL       L       240
# 89      Washington Wizards  2007-11-11    WAS @ ATL       W       240
# 110      Charlotte Hornets  2007-11-14    CHA @ ATL       L       240
# 125  Oklahoma City Thunder  2007-11-16    SEA @ ATL       W       290
#
#      FGM_AWAY  ...  Win  HomeWinStreak  AwayWinStreak  POINT_DIFF  \
# 23       35.0  ...    1              1              1           7
# 59       35.0  ...    1              2              1           9
# 89       38.0  ...    0              0              0         -11
# 110      41.0  ...    1              1              1           8
# 125      47.0  ...    0              0              0          -3
#
#      FG_EFF_HOME  FG_EFF_AWAY  FG3_EFF_HOME  FG3_EFF_AWAY  FT_EFF_HOME  \
# 23      0.455696     0.437500      0.266667      0.166667     0.806452
# 59      0.455556     0.406977      0.250000      0.407407     0.826087
# 89      0.389610     0.431818      0.150000      0.294118     0.771429
# 110     0.597403     0.493976      0.500000      0.500000     0.814815
# 125     0.454545     0.474747      0.260870      0.375000     0.818182
#
#      FT_EFF_AWAY
# 23      0.800000
# 59      0.882353
# 89      0.800000
# 110     0.703704
# 125     0.838710
#
# [5 rows x 75 columns]

# %% [markdown]
# ### Calculate Total Rebounds
#
# Sum offensive and defensive rebounds to get total rebounds for both home and away teams.

# %%
# Total rebounds
merged_df['REB_TOTAL_HOME'] = merged_df['OREB_HOME'] + merged_df['DREB_HOME']
merged_df['REB_TOTAL_AWAY'] = merged_df['OREB_AWAY'] + merged_df['DREB_AWAY']

# %%
merged_df.head()
# Out:
#       GAME_ID  SEASON_ID  TEAM_ID_AWAY TEAM_ABBREVIATION_AWAY  \
# 23   20700019      22007    1610612742                    DAL
# 59   20700056      22007    1610612756                    PHX
# 89   20700086      22007    1610612764                    WAS
# 110  20700106      22007    1610612766                    CHA
# 125  20700123      22007    1610612760                    OKC
#
#             TEAM_NAME_AWAY   GAME_DATE MATCHUP_AWAY WL_AWAY  MIN_AWAY  \
# 23        Dallas Mavericks  2007-11-02    DAL @ ATL       L       240
# 59            Phoenix Suns  2007-11-07    PHX @ ATL       L       240
# 89      Washington Wizards  2007-11-11    WAS @ ATL       W       240
# 110      Charlotte Hornets  2007-11-14    CHA @ ATL       L       240
# 125  Oklahoma City Thunder  2007-11-16    SEA @ ATL       W       290
#
#      FGM_AWAY  ...  AwayWinStreak  POINT_DIFF  FG_EFF_HOME  FG_EFF_AWAY  \
# 23       35.0  ...              1           7     0.455696     0.437500
# 59       35.0  ...              1           9     0.455556     0.406977
# 89       38.0  ...              0         -11     0.389610     0.431818
# 110      41.0  ...              1           8     0.597403     0.493976
# 125      47.0  ...              0          -3     0.454545     0.474747
#
#      FG3_EFF_HOME  FG3_EFF_AWAY  FT_EFF_HOME  FT_EFF_AWAY  REB_TOTAL_HOME  \
# 23       0.266667      0.166667     0.806452     0.800000            52.0
# 59       0.250000      0.407407     0.826087     0.882353            56.0
# 89       0.150000      0.294118     0.771429     0.800000            41.0
# 110      0.500000      0.500000     0.814815     0.703704            38.0
# 125      0.260870      0.375000     0.818182     0.838710            47.0
#
#      REB_TOTAL_AWAY
# 23             38.0
# 59             40.0
# 89             53.0
# 110            29.0
# 125            43.0
#
# [5 rows x 77 columns]

# %% [markdown]
# ### Calculate Rolling Averages
#
# Compute rolling averages for points and rebounds over the last 5 games for both home and away teams.

# %%
# Calculate rolling averages for home team stats (PTS, REB, etc.)
rolling_window = 5 

merged_df['Home_PTS_RollAvg'] = merged_df.groupby('HomeTeam')['PTS_HOME'].transform(lambda x: x.rolling(window=rolling_window, min_periods=1).mean())
merged_df['Home_REB_RollAvg'] = merged_df.groupby('HomeTeam')['REB_TOTAL_HOME'].transform(lambda x: x.rolling(window=rolling_window, min_periods=1).mean())

# %%
# Calculate rolling averages for away team stats (PTS, REB, etc.)

merged_df['Away_PTS_RollAvg'] = merged_df.groupby('AwayTeam')['PTS_AWAY'].transform(lambda x: x.rolling(window=rolling_window, min_periods=1).mean())
merged_df['Away_REB_RollAvg'] = merged_df.groupby('AwayTeam')['REB_TOTAL_AWAY'].transform(lambda x: x.rolling(window=rolling_window, min_periods=1).mean())

# %%
# List of all relevant columns
columns_of_interest = [
    'HomeTeam', 'PTS_HOME', 'REB_TOTAL_HOME',
    'AwayTeam', 'PTS_AWAY', 'REB_TOTAL_AWAY',
    'Home_PTS_RollAvg', 'Home_REB_RollAvg',
    'Away_PTS_RollAvg', 'Away_REB_RollAvg'
]

# Create a new DataFrame with these columns
subset_df = merged_df[columns_of_interest]

# Display the subset DataFrame
subset_df.head(10)
# Out:
#     HomeTeam  PTS_HOME  REB_TOTAL_HOME AwayTeam  PTS_AWAY  REB_TOTAL_AWAY  \
# 23       ATL       101            52.0      DAL        94            38.0
# 59       ATL       105            56.0      PHX        96            40.0
# 89       ATL        90            41.0      WAS       101            53.0
# 110      ATL       117            38.0      CHA       109            29.0
# 125      ATL       123            47.0      SEA       126            43.0
# 152      ATL        83            39.0      SAS        95            39.0
# 215      ATL        96            38.0      MIL        80            34.0
# 228      ATL        86            41.0      NOH        92            49.0
# 258      ATL        95            33.0      DET       106            39.0
# 273      ATL        90            40.0      MIN        89            53.0
#
#      Home_PTS_RollAvg  Home_REB_RollAvg  Away_PTS_RollAvg  Away_REB_RollAvg
# 23         101.000000         52.000000              94.0              38.0
# 59         103.000000         54.000000              96.0              40.0
# 89          98.666667         49.666667             101.0              53.0
# 110        103.250000         46.750000             109.0              29.0
# 125        107.200000         46.800000             126.0              43.0
# 152        103.600000         44.200000              95.0              39.0
# 215        101.800000         40.600000              80.0              34.0
# 228        101.000000         40.600000              92.0              49.0
# 258         96.600000         39.600000             106.0              39.0
# 273         90.000000         38.200000              89.0              53.0

# %% [markdown]
# ### Calculate Effective Field Goal Percentage
#
# Calculate the effective field goal percentage for both home (`EFG_HOME`) and away (`EFG_AWAY`) teams.

# %%
# Effective field goal percentage
merged_df['EFG_HOME'] = (merged_df['FGM_HOME'] + 0.5 * merged_df['FG3M_HOME']) / merged_df['FGA_HOME']
merged_df['EFG_AWAY'] = (merged_df['FGM_AWAY'] + 0.5 * merged_df['FG3M_AWAY']) / merged_df['FGA_AWAY']

# %%
merged_df.head()
# Out:
#       GAME_ID  SEASON_ID  TEAM_ID_AWAY TEAM_ABBREVIATION_AWAY  \
# 23   20700019      22007    1610612742                    DAL
# 59   20700056      22007    1610612756                    PHX
# 89   20700086      22007    1610612764                    WAS
# 110  20700106      22007    1610612766                    CHA
# 125  20700123      22007    1610612760                    OKC
#
#             TEAM_NAME_AWAY   GAME_DATE MATCHUP_AWAY WL_AWAY  MIN_AWAY  \
# 23        Dallas Mavericks  2007-11-02    DAL @ ATL       L       240
# 59            Phoenix Suns  2007-11-07    PHX @ ATL       L       240
# 89      Washington Wizards  2007-11-11    WAS @ ATL       W       240
# 110      Charlotte Hornets  2007-11-14    CHA @ ATL       L       240
# 125  Oklahoma City Thunder  2007-11-16    SEA @ ATL       W       290
#
#      FGM_AWAY  ...  FT_EFF_HOME  FT_EFF_AWAY  REB_TOTAL_HOME  REB_TOTAL_AWAY  \
# 23       35.0  ...     0.806452     0.800000            52.0            38.0
# 59       35.0  ...     0.826087     0.882353            56.0            40.0
# 89       38.0  ...     0.771429     0.800000            41.0            53.0
# 110      41.0  ...     0.814815     0.703704            38.0            29.0
# 125      47.0  ...     0.818182     0.838710            47.0            43.0
#
#      Home_PTS_RollAvg  Home_REB_RollAvg  Away_PTS_RollAvg  Away_REB_RollAvg  \
# 23         101.000000         52.000000              94.0              38.0
# 59         103.000000         54.000000              96.0              40.0
# 89          98.666667         49.666667             101.0              53.0
# 110        103.250000         46.750000             109.0              29.0
# 125        107.200000         46.800000             126.0              43.0
#
#      EFG_HOME  EFG_AWAY
# 23   0.481013  0.462500
# 59   0.477778  0.470930
# 89   0.409091  0.460227
# 110  0.616883  0.542169
# 125  0.484848  0.505051
#
# [5 rows x 83 columns]

# %% [markdown]
# ### Calculate Assist to Turnover Ratio
#
# Compute the assist to turnover ratio for both home and away teams.

# %%
# Assist to turnover ratio
merged_df['AST_TOV_RATIO_HOME'] = merged_df['AST_HOME'] / (merged_df['TOV_HOME'] + 1e-6)
merged_df['AST_TOV_RATIO_AWAY'] = merged_df['AST_AWAY'] / (merged_df['TOV_AWAY'] + 1e-6)

# %%
merged_df.head()
# Out:
#       GAME_ID  SEASON_ID  TEAM_ID_AWAY TEAM_ABBREVIATION_AWAY  \
# 23   20700019      22007    1610612742                    DAL
# 59   20700056      22007    1610612756                    PHX
# 89   20700086      22007    1610612764                    WAS
# 110  20700106      22007    1610612766                    CHA
# 125  20700123      22007    1610612760                    OKC
#
#             TEAM_NAME_AWAY   GAME_DATE MATCHUP_AWAY WL_AWAY  MIN_AWAY  \
# 23        Dallas Mavericks  2007-11-02    DAL @ ATL       L       240
# 59            Phoenix Suns  2007-11-07    PHX @ ATL       L       240
# 89      Washington Wizards  2007-11-11    WAS @ ATL       W       240
# 110      Charlotte Hornets  2007-11-14    CHA @ ATL       L       240
# 125  Oklahoma City Thunder  2007-11-16    SEA @ ATL       W       290
#
#      FGM_AWAY  ...  REB_TOTAL_HOME  REB_TOTAL_AWAY  Home_PTS_RollAvg  \
# 23       35.0  ...            52.0            38.0        101.000000
# 59       35.0  ...            56.0            40.0        103.000000
# 89       38.0  ...            41.0            53.0         98.666667
# 110      41.0  ...            38.0            29.0        103.250000
# 125      47.0  ...            47.0            43.0        107.200000
#
#      Home_REB_RollAvg  Away_PTS_RollAvg  Away_REB_RollAvg  EFG_HOME  EFG_AWAY  \
# 23          52.000000              94.0              38.0  0.481013  0.462500
# 59          54.000000              96.0              40.0  0.477778  0.470930
# 89          49.666667             101.0              53.0  0.409091  0.460227
# 110         46.750000             109.0              29.0  0.616883  0.542169
# 125         46.800000             126.0              43.0  0.484848  0.505051
#
#      AST_TOV_RATIO_HOME  AST_TOV_RATIO_AWAY
# 23             1.333333            1.400000
# 59             1.375000            1.400000
# 89             1.909091            2.166666
# 110            1.705882            1.357143
# 125            1.600000            1.769231
#
# [5 rows x 85 columns]

# %% [markdown]
# ### Calculate Home/Away Performance Ratios
#
# Determine the ratio of home team performance to away team performance in terms of field goals made and attempted.

# %%
# Home/away performance ratios
merged_df['HOME_AWAY_FGM_RATIO'] = merged_df['FGM_HOME'] / merged_df['FGM_AWAY']
merged_df['HOME_AWAY_FGA_RATIO'] = merged_df['FGA_HOME'] / merged_df['FGA_AWAY']

# %%
merged_df.head()
# Out:
#       GAME_ID  SEASON_ID  TEAM_ID_AWAY TEAM_ABBREVIATION_AWAY  \
# 23   20700019      22007    1610612742                    DAL
# 59   20700056      22007    1610612756                    PHX
# 89   20700086      22007    1610612764                    WAS
# 110  20700106      22007    1610612766                    CHA
# 125  20700123      22007    1610612760                    OKC
#
#             TEAM_NAME_AWAY   GAME_DATE MATCHUP_AWAY WL_AWAY  MIN_AWAY  \
# 23        Dallas Mavericks  2007-11-02    DAL @ ATL       L       240
# 59            Phoenix Suns  2007-11-07    PHX @ ATL       L       240
# 89      Washington Wizards  2007-11-11    WAS @ ATL       W       240
# 110      Charlotte Hornets  2007-11-14    CHA @ ATL       L       240
# 125  Oklahoma City Thunder  2007-11-16    SEA @ ATL       W       290
#
#      FGM_AWAY  ...  Home_PTS_RollAvg  Home_REB_RollAvg  Away_PTS_RollAvg  \
# 23       35.0  ...        101.000000         52.000000              94.0
# 59       35.0  ...        103.000000         54.000000              96.0
# 89       38.0  ...         98.666667         49.666667             101.0
# 110      41.0  ...        103.250000         46.750000             109.0
# 125      47.0  ...        107.200000         46.800000             126.0
#
#      Away_REB_RollAvg  EFG_HOME  EFG_AWAY  AST_TOV_RATIO_HOME  \
# 23               38.0  0.481013  0.462500            1.333333
# 59               40.0  0.477778  0.470930            1.375000
# 89               53.0  0.409091  0.460227            1.909091
# 110              29.0  0.616883  0.542169            1.705882
# 125              43.0  0.484848  0.505051            1.600000
#
#      AST_TOV_RATIO_AWAY  HOME_AWAY_FGM_RATIO  HOME_AWAY_FGA_RATIO
# 23             1.400000             1.028571             0.987500
# 59             1.400000             1.171429             1.046512
# 89             2.166666             0.789474             0.875000
# 110            1.357143             1.121951             0.927711
# 125            1.769231             0.957447             1.000000
#
# [5 rows x 87 columns]

# %% [markdown]
# ### Calculate Betting Odds Features
#
# Create features based on betting odds, such as spread differences and probability derived from moneyline odds.

# %%
# Corrected line to calculate SPREAD_DIFF
merged_df['SPREAD_DIFF'] = merged_df['HomeSpread_AtClose'] - merged_df['HomeSpread_AtOpen']
merged_df['OVER_DIFF'] = merged_df['Over_AtClose'] - merged_df['Over_AtOpen']

# Convert moneyline to probability
merged_df['HomeML'] = pd.to_numeric(merged_df['HomeML'], errors='coerce')
merged_df['AwayML'] = pd.to_numeric(merged_df['AwayML'], errors='coerce')

merged_df['HomeML_Prob'] = 1 / (1 + 10 ** ((merged_df['HomeML'] - 100) / 400))
merged_df['AwayML_Prob'] = 1 / (1 + 10 ** ((merged_df['AwayML'] - 100) / 400))
merged_df.dropna(subset=['HomeML', 'AwayML'], inplace=True)

# %%
merged_df.head()
# Out:
#       GAME_ID  SEASON_ID  TEAM_ID_AWAY TEAM_ABBREVIATION_AWAY  \
# 23   20700019      22007    1610612742                    DAL
# 59   20700056      22007    1610612756                    PHX
# 89   20700086      22007    1610612764                    WAS
# 110  20700106      22007    1610612766                    CHA
# 125  20700123      22007    1610612760                    OKC
#
#             TEAM_NAME_AWAY   GAME_DATE MATCHUP_AWAY WL_AWAY  MIN_AWAY  \
# 23        Dallas Mavericks  2007-11-02    DAL @ ATL       L       240
# 59            Phoenix Suns  2007-11-07    PHX @ ATL       L       240
# 89      Washington Wizards  2007-11-11    WAS @ ATL       W       240
# 110      Charlotte Hornets  2007-11-14    CHA @ ATL       L       240
# 125  Oklahoma City Thunder  2007-11-16    SEA @ ATL       W       290
#
#      FGM_AWAY  ...  EFG_HOME  EFG_AWAY  AST_TOV_RATIO_HOME  \
# 23       35.0  ...  0.481013  0.462500            1.333333
# 59       35.0  ...  0.477778  0.470930            1.375000
# 89       38.0  ...  0.409091  0.460227            1.909091
# 110      41.0  ...  0.616883  0.542169            1.705882
# 125      47.0  ...  0.484848  0.505051            1.600000
#
#      AST_TOV_RATIO_AWAY  HOME_AWAY_FGM_RATIO  HOME_AWAY_FGA_RATIO  \
# 23             1.400000             1.028571             0.987500
# 59             1.400000             1.171429             1.046512
# 89             2.166666             0.789474             0.875000
# 110            1.357143             1.121951             0.927711
# 125            1.769231             0.957447             1.000000
#
#      SPREAD_DIFF  OVER_DIFF  HomeML_Prob  AwayML_Prob
# 23          -0.5       -1.0     0.346783     0.882338
# 59          -0.5       -1.5     0.373301     0.869850
# 89          -0.5       -3.0     0.869850     0.373301
# 110         -0.5        0.5     0.876229     0.359935
# 125          1.5       -1.5     0.896477     0.314940
#
# [5 rows x 91 columns]

# %% [markdown]
# ### Calculate Half-Time Metrics
#
# Create new features based on differences between second-half and full-game spreads and totals.

# %%
# Half-time metrics
merged_df['2H_Spread_Diff'] = merged_df['2H_HomeSpread'] - merged_df['HomeSpread_AtClose']
merged_df['2H_Over_Diff'] = merged_df['2H_Over'] - merged_df['Over_AtClose']

# %%
merged_df.head()
# Out:
#       GAME_ID  SEASON_ID  TEAM_ID_AWAY TEAM_ABBREVIATION_AWAY  \
# 23   20700019      22007    1610612742                    DAL
# 59   20700056      22007    1610612756                    PHX
# 89   20700086      22007    1610612764                    WAS
# 110  20700106      22007    1610612766                    CHA
# 125  20700123      22007    1610612760                    OKC
#
#             TEAM_NAME_AWAY   GAME_DATE MATCHUP_AWAY WL_AWAY  MIN_AWAY  \
# 23        Dallas Mavericks  2007-11-02    DAL @ ATL       L       240
# 59            Phoenix Suns  2007-11-07    PHX @ ATL       L       240
# 89      Washington Wizards  2007-11-11    WAS @ ATL       W       240
# 110      Charlotte Hornets  2007-11-14    CHA @ ATL       L       240
# 125  Oklahoma City Thunder  2007-11-16    SEA @ ATL       W       290
#
#      FGM_AWAY  ...  AST_TOV_RATIO_HOME  AST_TOV_RATIO_AWAY  \
# 23       35.0  ...            1.333333            1.400000
# 59       35.0  ...            1.375000            1.400000
# 89       38.0  ...            1.909091            2.166666
# 110      41.0  ...            1.705882            1.357143
# 125      47.0  ...            1.600000            1.769231
#
#      HOME_AWAY_FGM_RATIO  HOME_AWAY_FGA_RATIO  SPREAD_DIFF  OVER_DIFF  \
# 23              1.028571             0.987500         -0.5       -1.0
# 59              1.171429             1.046512         -0.5       -1.5
# 89              0.789474             0.875000         -0.5       -3.0
# 110             1.121951             0.927711         -0.5        0.5
# 125             0.957447             1.000000          1.5       -1.5
#
#      HomeML_Prob  AwayML_Prob  2H_Spread_Diff  2H_Over_Diff
# 23      0.346783     0.882338            -0.5         -96.5
# 59      0.373301     0.869850             0.0        -103.5
# 89      0.869850     0.373301             0.5         -92.5
# 110     0.876229     0.359935             7.0         -94.5
# 125     0.896477     0.314940             0.5        -104.0
#
# [5 rows x 93 columns]

# %%
#efficiency metrics

merged_df['Offensive_Efficiency_HOME'] = merged_df['PTS_HOME'] / merged_df['REB_HOME']
merged_df['Defensive_Efficiency_HOME'] = merged_df['PTS_AWAY'] / merged_df['REB_HOME']
merged_df['Offensive_Efficiency_AWAY'] = merged_df['PTS_AWAY'] / merged_df['REB_AWAY']
merged_df['Defensive_Efficiency_AWAY'] = merged_df['PTS_HOME'] / merged_df['REB_AWAY']

# pace
merged_df['Pace_Home'] = merged_df['FGA_HOME'] + merged_df['FGA_AWAY']
merged_df['Pace_Away'] = merged_df['FGA_AWAY'] + merged_df['FGA_HOME']

# %%
# Drop any rows with NaN values after feature engineering
merged_df.dropna(inplace=True)

# %%
merged_df.head()
# Out:
#       GAME_ID  SEASON_ID  TEAM_ID_AWAY TEAM_ABBREVIATION_AWAY  \
# 23   20700019      22007    1610612742                    DAL
# 59   20700056      22007    1610612756                    PHX
# 89   20700086      22007    1610612764                    WAS
# 110  20700106      22007    1610612766                    CHA
# 125  20700123      22007    1610612760                    OKC
#
#             TEAM_NAME_AWAY   GAME_DATE MATCHUP_AWAY WL_AWAY  MIN_AWAY  \
# 23        Dallas Mavericks  2007-11-02    DAL @ ATL       L       240
# 59            Phoenix Suns  2007-11-07    PHX @ ATL       L       240
# 89      Washington Wizards  2007-11-11    WAS @ ATL       W       240
# 110      Charlotte Hornets  2007-11-14    CHA @ ATL       L       240
# 125  Oklahoma City Thunder  2007-11-16    SEA @ ATL       W       290
#
#      FGM_AWAY  ...  HomeML_Prob  AwayML_Prob  2H_Spread_Diff  2H_Over_Diff  \
# 23       35.0  ...     0.346783     0.882338            -0.5         -96.5
# 59       35.0  ...     0.373301     0.869850             0.0        -103.5
# 89       38.0  ...     0.869850     0.373301             0.5         -92.5
# 110      41.0  ...     0.876229     0.359935             7.0         -94.5
# 125      47.0  ...     0.896477     0.314940             0.5        -104.0
#
#      Offensive_Efficiency_HOME  Defensive_Efficiency_HOME  \
# 23                    1.942308                   1.807692
# 59                    1.875000                   1.714286
# 89                    2.195122                   2.463415
# 110                   3.078947                   2.868421
# 125                   2.617021                   2.680851
#
#      Offensive_Efficiency_AWAY  Defensive_Efficiency_AWAY  Pace_Home  \
# 23                    2.473684                   2.657895      159.0
# 59                    2.400000                   2.625000      176.0
# 89                    1.905660                   1.698113      165.0
# 110                   3.758621                   4.034483      160.0
# 125                   2.930233                   2.860465      198.0
#
#      Pace_Away
# 23       159.0
# 59       176.0
# 89       165.0
# 110      160.0
# 125      198.0
#
# [5 rows x 99 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize missing data for merged_df
plt.figure(figsize=(12, 8))
sns.heatmap(merged_df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Data Heatmap: merged_df')
plt.show()

# %%
# Count the number of columns in merged_df
num_columns = len(merged_df.columns)
print(f'Number of columns: {num_columns}')
# Out:
# Number of columns: 99

# %% [markdown]
# ## Load DataFrame to MySQL Database

# %%
from sqlalchemy import create_engine, text
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Insert Database connection details
user = 'root'
password = 'binaryval1326'
host = 'localhost'
port = 3307 
database = 'nba_database'

# Create connection string
connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}'

# Create SQLAlchemy engine
engine = create_engine(connection_string)

# %%
# Define the table name
table_name = 'betting_and_game_table'

# Drop the table if it exists and create a new one
with engine.connect() as conn:
    conn.execute(text(f"DROP TABLE IF EXISTS {table_name}"))

# Save DataFrame to SQL
merged_df.to_sql(table_name, con=engine, if_exists='replace', index=False)

# Query the database and load data into a DataFrame to confirm
df_sql = pd.read_sql(f'SELECT * FROM {table_name};', con=engine)

# %%
# Verify the data upload by reading from the table

# Read the first few rows from the table
df_from_db = pd.read_sql(f'SELECT * FROM {table_name}', con=engine)
df_from_db.head()
# Out:
#     GAME_ID  SEASON_ID  TEAM_ID_AWAY TEAM_ABBREVIATION_AWAY  \
# 0  20700019      22007    1610612742                    DAL
# 1  20700056      22007    1610612756                    PHX
# 2  20700086      22007    1610612764                    WAS
# 3  20700106      22007    1610612766                    CHA
# 4  20700123      22007    1610612760                    OKC
#
#           TEAM_NAME_AWAY   GAME_DATE MATCHUP_AWAY WL_AWAY  MIN_AWAY  FGM_AWAY  \
# 0       Dallas Mavericks  2007-11-02    DAL @ ATL       L       240      35.0
# 1           Phoenix Suns  2007-11-07    PHX @ ATL       L       240      35.0
# 2     Washington Wizards  2007-11-11    WAS @ ATL       W       240      38.0
# 3      Charlotte Hornets  2007-11-14    CHA @ ATL       L       240      41.0
# 4  Oklahoma City Thunder  2007-11-16    SEA @ ATL       W       290      47.0
#
#    ...  HomeML_Prob  AwayML_Prob  2H_Spread_Diff  2H_Over_Diff  \
# 0  ...     0.346783     0.882338            -0.5         -96.5
# 1  ...     0.373301     0.869850             0.0        -103.5
# 2  ...     0.869850     0.373301             0.5         -92.5
# 3  ...     0.876229     0.359935             7.0         -94.5
# 4  ...     0.896477     0.314940             0.5        -104.0
#
#    Offensive_Efficiency_HOME  Defensive_Efficiency_HOME  \
# 0                   1.942308                   1.807692
# 1                   1.875000                   1.714286
# 2                   2.195122                   2.463415
# 3                   3.078947                   2.868421
# 4                   2.617021                   2.680851
#
#    Offensive_Efficiency_AWAY  Defensive_Efficiency_AWAY  Pace_Home  Pace_Away
# 0                   2.473684                   2.657895      159.0      159.0
# 1                   2.400000                   2.625000      176.0      176.0
# 2                   1.905660                   1.698113      165.0      165.0
# 3                   3.758621                   4.034483      160.0      160.0
# 4                   2.930233                   2.860465      198.0      198.0
#
# [5 rows x 99 columns]
